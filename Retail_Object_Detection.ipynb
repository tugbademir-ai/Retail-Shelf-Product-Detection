# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.5/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KNoSYmfC7enkIcF6GXYc")
project = rf.workspace("identvintern").project("groceries-9vwuo")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO


model = YOLO('yolov8n.pt')


print("Eğitim Başlıyor... Arkana yaslan.")
results = model.train(data=f"{dataset.location}/data.yaml", epochs=25, imgsz=640)
# Out:
# Eğitim Başlıyor... Arkana yaslan.
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, display
import os

# Eğitim sonuçlarının olduğu klasörü bul
results_dir = model.trainer.save_dir

# Başarı grafiğini ekrana bas (Bu grafiği indirip GitHub'a koyacağız)
print(f"Sonuçlar burada: {results_dir}")
display(Image(filename=f'{results_dir}/results.png'))
# Out:
# Sonuçlar burada: /content/runs/detect/train2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2934864662.py in <cell line: 0>()
#       7 # Başarı grafiğini ekrana bas (Bu grafiği indirip GitHub'a koyacağız)
#       8 print(f"Sonuçlar burada: {results_dir}")
# ----> 9 display(Image(filename=f'{results_dir}/results.png'))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
# ...
